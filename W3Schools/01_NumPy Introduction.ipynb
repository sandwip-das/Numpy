# %% [markdown]
# # NumPy Introduction
# ### Source:
# - W3 Schools

# %% [markdown]
# ## What is NumPy?
# NumPy was created in 2005 by merging two earlier numerical packages (Numeric and Numarray) to solve Python's shortcomings in numerical computing—specifically, efficient array handling and mathematical operations. Built largely in C for speed, it quickly became a critical, high-performance module in the scientific Python community.
#
# Today, NumPy is a cornerstone of the Python data ecosystem, providing the foundation for major data science and machine learning libraries like Pandas, scikit-learn, and TensorFlow. Its importance continues to grow with the rise of data science and AI, making mastery of NumPy essential.
# - NumPy is a Python library used for working with arrays.
# - It also has functions for working in domain of linear algebra, fourier transform, and matrices.
# - NumPy was created in 2005 by Travis Oliphant. It is an open source project and you can use it freely.
# - NumPy stands for Numerical Python.

# %% [markdown]
# ## Why Use NumPy?
# - In Python we have lists that serve the purpose of arrays, but they are slow to process.
# - NumPy aims to provide an array object that is up to 50x faster than traditional Python lists.
# - The array object in NumPy is called <mark>ndarray</mark>, it provides a lot of supporting functions that make working with ndarray very easy.
# - Arrays are very frequently used in data science, where speed and resources are very important.

# %% [markdown]
# ## Why is NumPy Faster Than Lists?
# - NumPy arrays are stored at one continuous place in memory unlike lists, so processes can access and manipulate them very efficiently.
# - This behavior is called locality of reference in computer science.
# - This is the main reason why NumPy is faster than lists. Also it is optimized to work with latest CPU architectures.

# %% [markdown]
# ## Which Language is NumPy written in?
# - NumPy is a Python library and is written partially in Python, but most of the parts that require fast computation are written in C or C++.

# %% [markdown]
# ## Installation of NumPy
# - NumPy is not part of the default Python distribution, so you’ll need to install it. If you have Python and PIP already installed on a system, then installation of NumPy is very easy.
# - Install it using this command:
# - By using the terminal command: <b>pip install numpy
# - For Conda user: <b> conda install numpy

# %% [markdown]
# ## Import NumPy
# - Like all packages, you can import parts of NumPy or the entire package. Import it in your applications by adding the import keyword:

# %%
import numpy
arr = numpy.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ## NumPy as np
# - There’s a convention to import the entire package and rename it to np. It’s strongly recommended to use this convention as well.
# - NumPy is usually imported under the np alias.
# - <b>alias:</b> In Python, an alias is an alternate name for referring to the same thing.
# - Create an alias with the as keyword while importing: *** Best Practice

# %%
import numpy as np  # Now the NumPy package can be referred to as np instead of numpy.
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ## Checking NumPy Version
# - The version string is stored under __version__ attribute.

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.3.5

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.3.5

# %%
File → Insert Notebook → From File

# %%
File → Insert Notebook → From File
